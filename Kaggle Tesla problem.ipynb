# %% [markdown]
# # Kaggle Tesla stock dta 2010-2020

# %%
"""
Title  : Linear Regression Problem Tesla
Author : Akshay Unde
Date   : 07/02/2020 
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load Dataset
Tesla_dataset = pd.read_csv("TSLA.csv")

# %%
#print dataset
Tesla_dataset
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# ...

# %%
#Check dataset head
Tesla_dataset.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
#check any data cell is Empty or not using heamap
sns.heatmap(Tesla_dataset.isnull())

# %%
#Drow Pairplot using detaset
sns.pairplot(Tesla_dataset)

# %%
Tesla_dataset.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
#Train and test dataset
from sklearn.model_selection import train_test_split

# %%
#set x and y data
x=Tesla_dataset[['High','Low','Close']]
y=Tesla_dataset['Volume']

# %%
#check head of x
x.head()
# Out:
#     High        Low      Close
# 0  25.00  17.540001  23.889999
# 1  30.42  23.299999  23.830000
# 2  25.92  20.270000  21.959999
# 3  23.10  18.709999  19.200001
# 4  20.00  15.830000  16.110001

# %%
#check head of y
y.head()
# Out:
# 0    18766300
# 1    17187100
# 2     8218800
# 3     5139800
# 4     6866900
# Name: Volume, dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 3 columns):
# High     2416 non-null float64
# Low      2416 non-null float64
# Close    2416 non-null float64
# dtypes: float64(3)
# memory usage: 56.8 KB

# %%
#trane First 30% data send to testting
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.30)

# %%
X_train.head()
# Out:
#             High         Low       Close
# 2143  309.399994  297.380005  300.359985
# 1958  307.100006  293.679993  304.700012
# 1224  242.880005  235.309998  239.490005
# 69     21.260000   20.320000   20.459999
# 569    29.889999   28.610001   29.280001

# %%
X_train.count()
# Out:
# High     1691
# Low      1691
# Close    1691
# dtype: int64

# %%
X_test.head()
# Out:
#             High         Low       Close
# 37     19.110001   18.510000   19.100000
# 226    28.280001   27.350000   27.969999
# 607    32.299999   31.620001   32.270000
# 2289  236.270004  229.229996  234.339996
# 2274  245.380005  239.710007  245.080002

# %%
#check X_test count number
X_test.count()
# Out:
# High     725
# Low      725
# Close    725
# dtype: int64

# %%
y_train.count()
# Out:
# 1691

# %%
#Import LinearRegression
from sklearn.linear_model import LinearRegression

# %%
#create object linearregeression
Teslaregression = LinearRegression()

# %%
#send test data to LinearRegression object
Teslaregression.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#predict
Teslaregression.predict([[75, 250,10]])
# Out:
# array([-94680471.79221311])

# %%
#Stor all Predict datato ypredict object
y_predict = Teslaregression.predict(X_test)

# %%
#check is stor or not
y_predict[2]
# Out:
# 1773420.2658987734

# %%
# Genrate Scatter Graph
plt.title=("Tesla Prediction")
plt.xlabel("X label")
plt.ylabel("Y label")

plt.scatter(y_predict,y_test, c=['r'], alpha = 0.2, marker=r'$\clubsuit$')

# %%
# More understand to use color in Scatter graph
N=3
plt.title=("Tesla Prediction")
plt.xlabel("X label")
plt.ylabel("Y label")
colors = np.random.rand(N)
plt.scatter(y_predict,y_test, c=colors, alpha = 0.8, marker=r'$\clubsuit$')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
